# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

from data_cleaner import get_dataset

# %%
# append all the jobs data
roles = ["Data Science", "Software Engineer"]
locations = ["San Francisco", "New York", "Toronto", "Vancouver"]
jobs_df = pd.DataFrame()
for role in roles:
    for location in locations:
        job_data = get_dataset('glassdoor_jobs_' + role.replace(" ","_") + '_' + \
                                                  location.replace(" ","_") + '.csv')
        job_data["Category"] = role
        jobs_df = pd.concat([jobs_df, job_data], ignore_index=True)
jobs_df.head()
# Out:
#                                       Job Title         Job Company  \
# 0      Senior Data Scientist - Ads Optimization              Indeed
# 1  Technical Sourcer - Data Science & Analytics                Uber
# 2                   Senior Data Science Analyst      JM Talent Inc.
# 3                         Data Science Lecturer  Excelon Associates
# 4                                Data Scientist      Warman O'Brien
#
#         Job Location  Company Rating  Company Rating Numbers  \
# 0  San Francisco, CA             4.3                     703
# 1  San Francisco, CA             4.0                    3142
# 2        Oakland, CA             0.0                       0
# 3       Berkeley, CA             4.8                       1
# 4  San Francisco, CA             5.0                       0
#
#         Company Size  Company Founded       Company Type  \
# 0   10000+ Employees             2004  Company - Private
# 1   10000+ Employees             2009   Company - Public
# 2            Unknown                0   Company - Public
# 3  1 to 50 Employees             2007  Company - Private
# 4  1 to 50 Employees             2017  Company - Private
#
#          Company Industry          Company Sector             Company Revenue  \
# 0                Internet  Information Technology      $2 to $5 billion (USD)
# 1                Internet  Information Technology          $10+ billion (USD)
# 2                 Unknown                 Unknown    Unknown / Non-Applicable
# 3  Staffing & Outsourcing       Business Services  Less than $1 million (USD)
# 4  Staffing & Outsourcing       Business Services     $5 to $10 million (USD)
#
#     Level   Minimum   Maximum Currency      Category Company
# 0  Senior  153000.0  223000.0      USD  Data Science      NaN
# 1  Normal   87000.0  167000.0      USD  Data Science      NaN
# 2  Senior  100000.0  100000.0      USD  Data Science      NaN
# 3  Normal   62000.0  162000.0      USD  Data Science      NaN
# 4  Normal  120000.0  140000.0      USD  Data Science      NaN

# %%
# Add Roles for each job:
def role(title, job_type):
    if job_type == "Software Engineer":
        if "test" in title.lower() or "qa" in title.lower() or "quality" in title.lower():
            return "Test"
        elif "backend" in title.lower():
            return "BackEnd"
        elif "frontend" in title.lower():
            return "FrontEnd"
        elif "full stack" in title.lower() or "developer" in title.lower():
            return "Full Stack"
        elif "infra" in title.lower() or "system" in title.lower() or "devops" in title.lower():
            return "Infra/System SWE"
        elif "cloud" in title.lower() or "data" in title.lower() or "analysis" in title.lower() \
        or "analytics" in title.lower():
            return "Data SWE"
        else:
            return "SWE"
    elif job_type == "Data Science":
        if "quantitative" in title.lower():
            if "analyst" in title.lower():
                return "Quantitative Analyst"
            elif "research" in title.lower():
                return "Quantitative Researcher"
            else:
                return "Quantitative Data"
        elif "engineer" in title.lower():
            return "Data Engineer"
        elif "research" in title.lower() or "deep learning" in title.lower():
            return "Data Researcher"
        elif "analyst" in title.lower() or "analysis" in title.lower() or "analytics" in title.lower():
            return "Data Analyst"
        elif "science" in title.lower() or "scientist" in title.lower():
            return "Data Science"
        else:
            "General Data"
    else:
        return ""
    
jobs_df["Role"] = jobs_df.apply(lambda x: role(x['Job Title'], x['Category']), axis=1)
jobs_df
# Out:
#                                          Job Title  \
# 0         Senior Data Scientist - Ads Optimization
# 1     Technical Sourcer - Data Science & Analytics
# 2                      Senior Data Science Analyst
# 3                            Data Science Lecturer
# 4                                   Data Scientist
# ...                                            ...
# 5656                   Software Engineer - C#/.Net
# 5657                               DevOps Engineer
# 5658                           Software Engineer 1
# 5659      Software Engineer / Full Stack Developer
# 5660                             software engineer
#
#                         Job Company       Job Location  Company Rating  \
# 0                            Indeed  San Francisco, CA             4.3
# 1                              Uber  San Francisco, CA             4.0
# 2                    JM Talent Inc.        Oakland, CA             0.0
# 3                Excelon Associates       Berkeley, CA             4.8
# 4                    Warman O'Brien  San Francisco, CA             5.0
# ...                             ...                ...             ...
# 5656                       Canalyst          Vancouver             3.3
# 5657                        Prenuvo          Vancouver             5.0
# 5658  WELL Health Technologies Corp          Vancouver             2.8
# 5659                MPM Engineering             Surrey             0.0
# 5660      postalong technology inc.           Richmond             0.0
#
#       Company Rating Numbers         Company Size  Company Founded  \
# 0                        703     10000+ Employees             2004
# 1                       3142     10000+ Employees             2009
# 2                          0              Unknown                0
# 3                          1    1 to 50 Employees             2007
# 4                          0    1 to 50 Employees             2017
# ...                      ...                  ...              ...
# 5656                       8  51 to 200 Employees                0
# 5657                       4    1 to 50 Employees                0
# 5658                       0              Unknown                0
# 5659                       0              Unknown                0
# 5660                       0              Unknown                0
#
#            Company Type                         Company Industry  \
# 0     Company - Private                                 Internet
# 1      Company - Public                                 Internet
# 2      Company - Public                                  Unknown
# 3     Company - Private                   Staffing & Outsourcing
# 4     Company - Private                   Staffing & Outsourcing
# ...                 ...                                      ...
# 5656            Unknown  Enterprise Software & Network Solutions
# 5657  Company - Private         Health Care Services & Hospitals
# 5658  Company - Private                                  Unknown
# 5659  Company - Private                                  Unknown
# 5660            Unknown                                  Unknown
#
#               Company Sector             Company Revenue   Level   Minimum  \
# 0     Information Technology      $2 to $5 billion (USD)  Senior  153000.0
# 1     Information Technology          $10+ billion (USD)  Normal   87000.0
# 2                    Unknown    Unknown / Non-Applicable  Senior  100000.0
# 3          Business Services  Less than $1 million (USD)  Normal   62000.0
# 4          Business Services     $5 to $10 million (USD)  Normal  120000.0
# ...                      ...                         ...     ...       ...
# 5656  Information Technology    Unknown / Non-Applicable  Normal   72000.0
# 5657             Health Care    Unknown / Non-Applicable  Normal   81000.0
# 5658                 Unknown    Unknown / Non-Applicable  Normal   80000.0
# 5659                 Unknown    Unknown / Non-Applicable  Normal   53000.0
# 5660                 Unknown                     Unknown  Normal   99840.0
#
#        Maximum Currency           Category Company               Role
# 0     223000.0      USD       Data Science      NaN      Data Science
# 1     167000.0      USD       Data Science      NaN      Data Analyst
# 2     100000.0      USD       Data Science      NaN      Data Analyst
# 3     162000.0      USD       Data Science      NaN      Data Science
# 4     140000.0      USD       Data Science      NaN      Data Science
# ...        ...      ...                ...      ...               ...
# 5656  100000.0       CA  Software Engineer      NaN               SWE
# 5657  117000.0       CA  Software Engineer      NaN  Infra/System SWE
# 5658  119000.0       CA  Software Engineer      NaN               SWE
# 5659   89000.0       CA  Software Engineer      NaN        Full Stack
# 5660   99840.0       CA  Software Engineer      NaN               SWE
#
# [5661 rows x 18 columns]

# %%
# display value histogram for for Role, Location, and Level
jobs_df.Role.value_counts()
# Out:
# SWE                 1779
# Data Science        1357
# Data Analyst         784
# Full Stack           652
# Data Engineer        471
# Data Researcher      133
# BackEnd              124
# FrontEnd             115
# Infra/System SWE      99
# Data SWE              42
# Test                  21
# Name: Role, dtype: int64

# %%
jobs_df.Level.value_counts()
# Out:
# Normal    3852
# Senior    1495
# Junior     294
# Intern      20
# Name: Level, dtype: int64

# %%
jobs_df['Job Location'].value_counts()
# Out:
# San Francisco, CA       1695
# New York, NY            1664
# Vancouver                775
# Toronto                  755
# Mississauga              137
# Langley                   58
# Richmond                  52
# Burnaby                   52
# California                49
# Brooklyn, NY              39
# Surrey                    37
# North Vancouver           36
# Oakville                  33
# Burlingame, CA            27
# Brampton                  26
# White Plains, NY          26
# New York State            23
# Richmond Hill             17
# Berkeley, CA              17
# Newark, NJ                16
# Bronx, NY                 16
# Martinez, CA              15
# Staten Island, NY         14
# Mississauga Valley        10
# Long Island City, NY       7
# Oakland, CA                7
# Vaughan                    7
# Markham                    5
# Midtown Toronto            4
# Menlo Park, CA             4
# North York                 4
# Etobicoke                  4
# San Mateo, CA              3
# Queens Village, NY         3
# Alameda, CA                3
# Jersey City, NJ            3
# North Hills, NY            2
# Woodbridge                 2
# Delta                      2
# New Westminster            2
# Greenvale, NY              2
# Canada                     2
# Edgewater, NJ              1
# Pearl River, NY            1
# Lake Success, NY           1
# Scarborough                1
# Oceanside, NY              1
# New Hyde Park, NY          1
# Name: Job Location, dtype: int64

# %%
# Display histogram for company rating and year founded
jobs_df["Company Rating"].hist()
# Out:
# <AxesSubplot:>

# %%
jobs_df["Company Founded"].hist(bins=range(1800, 2020)) # histogram beside founded in year 0
# can be seen that many companies were built in year 2000+
# Out:
# <AxesSubplot:>

# %%
jobs_df.boxplot(column = ['Company Rating Numbers','Company Rating'])
# need normalization otherwise the rating nums will overtake rating value
# Out:
# <AxesSubplot:>

# %%
jobs_df.boxplot(column = ['Company Rating'])
# Out:
# <AxesSubplot:>

# %%
jobs_df[['Minimum','Maximum','Company Rating']].corr()
# Out:
#                  Minimum   Maximum  Company Rating
# Minimum         1.000000  0.742045        0.208974
# Maximum         0.742045  1.000000        0.278002
# Company Rating  0.208974  0.278002        1.000000

# %%
# check correlation with given role by converting role to int
role_list = list(set(jobs_df['Role'].to_list()))
role_list.remove(None)

role_int = jobs_df['Role'].apply(lambda x: role_list.index(x))
# correlation with roles
jobs_df[['Minimum','Maximum','Company Rating']].corrwith(role_int)
# Out:
# ['SWE', 'FrontEnd', 'Data Researcher', 'Full Stack', 'Test', 'Data Analyst', 'BackEnd', 'Data SWE', 'Data Science', 'Data Engineer', 'Infra/System SWE']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-92a0bafe2a8c> in <module>
#       5 print(role_list)
#       6
# ----> 7 role_int = jobs_df['Role'].apply(lambda x: role_list.index(x))
#       8 # correlation with roles
#       9 jobs_df[['Minimum','Maximum','Company Rating']].corrwith(role_int)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-32-92a0bafe2a8c> in <lambda>(x)
#       5 print(role_list)
#       6
# ----> 7 role_int = jobs_df['Role'].apply(lambda x: role_list.index(x))
#       8 # correlation with roles
#       9 jobs_df[['Minimum','Maximum','Company Rating']].corrwith(role_int)
#
# ValueError: None is not in list
